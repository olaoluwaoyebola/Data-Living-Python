# %%
# How to print using python
print("I am a boy")
# Out:
# I am a boy

# %% [markdown]
# ### NOTES
# 1. Variables

# %%
age = 5
print(age)
# Out:
# 5

# %%
age = 5
age
# Out:
# 5

# %%
blocks = 10
print(type(blocks))
# Out:
# <class 'int'>

# %%
print(blocks + 2)
# Out:
# 12

# %%
# Examples of float
juice = 2.5
print(type(juice))
# Out:
# <class 'float'>

# %%
print(juice * 2)
# Out:
# 5.0

# %%
# Examples of strings
name = "Luna the Cat"
print(type(name))
# Out:
# <class 'str'>

# %%
print("Hi,", name)
# Out:
# Hi, Luna the Cat

# %%
# Examples of Variables
is_hungry = False
print(type(is_hungry))
# Out:
# <class 'bool'>

# %%
print("Snack time?" if is_hungry else "Play more!")
# Out:
# Play more!

# %%
apples = 4
oranges = 3
total_fruit = apples + oranges
print(total_fruit)
# Out:
# 7

# %%
half_apples = apples / 2
print(half_apples)
# Out:
# 2.0

# %%
half_apples = apples / 2
half_apples
# Out:
# 2.0

# %%
print(2 ** 3)
# Out:
# 8

# %%
print(2 * 3)
# Out:
# 6

# %%
print(8 - 2)
# Out:
# 6

# %%
print(2 + 2)
# Out:
# 4

# %%
a = 14 / 2
a
# Out:
# 7.0

# %%
a = 14 // 2
a
# Out:
# 7

# %%
a = 14 / 3
a
# Out:
# 4.666666666666667

# %%
a = 14 // 3
a
# Out:
# 4

# %%
a = 14 % 3
a
# Out:
# 2

# %%
Modupe = 5
print(Modupe)
# Out:
# 5

# %%
name = "Abdul"
print("Hi,", name, "! You are awesome.")
# Out:
# Hi, Abdul ! You are awesome.

# %%
name = input("What's your name? ")
print("Hi,", name, "! You are awesome.")
# Out:
# Hi, Chidex ! You are awesome.

# %%
mood = input("Tell me your mood? ").upper()
if mood == "HAPPY":
    print("Yay! Dance party! 🎉")
elif mood == "sad":
    print("Hug time! 🤗")
else:
    print("Tell me more!")
# Out:
# Yay! Dance party! 🎉

# %%
mood = input("Tell me your mood? ").lower() # Makes lowercase
if mood == "happy":
    print("Yay! Dance party! 🎉")
elif mood == "sad":
    print("Hug time! 🤗")
else:
    print("Tell me more!")
# Out:
# Tell me more!

# %% [markdown]
# # Assignment Corrections

# %% [markdown]
# ### Exercise 1

# %%
age = 30 # integer
print(age)
print(type(age))
# Out:
# 30
# <class 'int'>

# %%
print("Chidex")
# Out:
# Chidex

# %%
name = "Chidex"
print(name)
# Out:
# Chidex

# %%
name = "Chidex" # string
print("Hi,", name)
# Out:
# Hi, Chidex

# %%
is_sunny = True
print(is_sunny)
# Out:
# True

# %%
height_feet = 5.9 # float
height_inches = height_feet * 12
print(height_inches)
# Out:
# 70.80000000000001

# %% [markdown]
# ## Exercise 2

# %%
apples = 6
oranges = 4
total = apples + oranges
average = total / 2 # simple average
leftovers = total % 5 # remainder when divided by 5
print("Total:", total)
print("Average:", average)
print("Leftovers if shared by 5:", leftovers)
# Out:
# Total: 10
# Average: 5.0
# Leftovers if shared by 5: 0

# %%
greeting = "Hello"
full_greeting = greeting + ", world!"
print(full_greeting)
fun_repeat = "Fun! " * 3
print(fun_repeat)
# Out:
# Hello, world!
# Fun! Fun! Fun!

# %%
name = input("What's your name? ")
print("Nice to meet you,", name + "!")
age = int(input("How old are you? "))
print("Next year I will be", age + 1)
# Out:
# Nice to meet you, !
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 3
#       1 name = input("What's your name? ")
#       2 print("Nice to meet you,", name + "!")
# ----> 3 age = int(input("How old are you? "))
#       4 print("Next year I will be", age + 1)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
number = int(input("Enter a number: "))
if number > 10:
    print("Big!")
elif number > 5 :
    print("Medium!")
else:
    print("Small!")
# Out:
# Small!

# %%
number = int(input("Enter a number: "))
if number >= 10:
    print("ten and above")
elif number > 5 or number < 9:
    print("Happy")
else:
    print("Unhappy")
# Out:
# Happy

# %%
number = int(input("Enter a number: "))
if number >= 10:
    print("ten and above")
elif number > 5 and number < 9:
    print("Happy")
else:
    print("Unhappy")
# Out:
# Happy

# %% [markdown]
# ### List

# %%
fruits = ["apple", "banana", "cherry"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits[2]
# Out:
# 'cherry'

# %%
fruits.append("grape")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'grape']

# %%
fruits.pop(2)
print(fruits)
# Out:
# ['banana', 'cherry']

# %%
len(fruits)
# Out:
# 2

# %%
fruits = ["apple", "banana", "cherry"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits.append("grape")
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'grape']

# %%
fruits.pop(2)
print(fruits)
# Out:
# ['apple', 'banana', 'grape']

# %%
fruits.pop(0)
print(fruits)
# Out:
# ['banana', 'grape']

# %%
fruits.append("mango", "pear", "pineapple")
print(fruits)
# Out:
# ['banana', 'grape', 'pear']

# %%
fruits.extend(["mango", "pear", "pineapple"])
print(fruits)
# Out:
# ['banana', 'grape', 'pear', 'mango', 'pear', 'pineapple']

# %%
fruits.insert(3, "watermelon")
print(fruits)
# Out:
# ['banana', 'grape', 'pear', 'watermelon', 'mango', 'pear', 'pineapple']

# %%
fruits = ['banana', 'grape', 'pear', 'watermelon', 'mango', 'pineapple']
idxs = [5, 4, 2]
popped = [fruits.pop(i) for i in (idxs)]
print(popped)
# Out:
# ['pineapple', 'mango', 'pear']

# %%
fruits = ['banana', 'grape', 'pear', 'watermelon', 'mango', 'pineapple']
idxs = [5, 4, 2]
popped = [fruits.pop(i) for i in sorted(idxs, reverse=True)]
print(popped)
# Out:
# ['pineapple', 'mango', 'pear']

# %%
print(fruits)
# Out:
# ['banana', 'grape', 'watermelon', 'pear']

# %%
fruits = ['banana', 'grape', 'pear', 'watermelon', 'mango', 'pear', 'pineapple']
popped = fruits[2:5]
print(popped)
print(fruits)
# Out:
# ['pear', 'watermelon', 'mango']
# ['banana', 'grape', 'pear', 'watermelon', 'mango', 'pear', 'pineapple']

# %%
fruits = ['banana', 'grape', 'pear', 'watermelon', 'mango', 'pear', 'pineapple']
popped = fruits[2:5]
del fruits[2:5]
print(popped)
print(fruits)
# Out:
# ['pear', 'watermelon', 'mango']
# ['banana', 'grape', 'pear', 'pineapple']

# %%
fruits = ['banana', 'grape', 'pear', 'watermelon', 'mango', 'pear', 'pineapple']
for name in ("mango", "pear", "pineapple"):
    while name in fruits:
        fruits.remove(name)
print(fruits)
# Out:
# ['banana', 'grape', 'watermelon']

# %%
toys = ["ball", 5, True]

# %%
for fruit in fruits:
    print(fruit)
# Out:
# banana
# grape
# watermelon

# %% [markdown]
# ### Tuple

# %%
skewers = ("apple", "banana", "cherry")
print(skewers)
# Out:
# ('apple', 'banana', 'cherry')

# %%
skewers[0]
# Out:
# 'apple'

# %%
skewers[1] = "orange"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 skewers[1] = "orange"
#
# TypeError: 'tuple' object does not support item assignment

# %%
len(skewers)
# Out:
# 3

# %%
toys = ("ball", 5, True)
print(toys)
# Out:
# ('ball', 5, True)

# %% [markdown]
# ### Dictionaries

# %%
fruit_map = {"apple": "red", "banana": "yellow", "cherry": "sweet"}
print(fruit_map)
# Out:
# {'apple': 'red', 'banana': 'yellow', 'cherry': 'sweet'}

# %%
fruit_map["apple"]
# Out:
# 'red'

# %%
fruit_map["grape"] = "purple"
print(fruit_map)
# Out:
# {'apple': 'red', 'banana': 'yellow', 'cherry': 'sweet', 'grape': 'purple'}

# %%
del fruit_map["cherry"]
print(fruit_map)
# Out:
# {'apple': 'red', 'banana': 'yellow', 'grape': 'purple'}

# %%
fruit_map.keys()
# Out:
# dict_keys(['apple', 'banana', 'grape'])

# %%
# List
fruits = ["apple", "banana"]
fruits.append("cherry")
print(fruits)

# Tuple
coords = (3, 4) # can't change
print(coords[0])

# Dictionary
toys = {"ball": "bouncy", "doll": "huggable"}
print(toys["ball"])
# Out:
# ['apple', 'banana', 'cherry']
# 3
# bouncy

# %% [markdown]
# # For Loop

# %%
for i in range(5):
    print("Count:", i + 1)
# Out:
# Count: 1
# Count: 2
# Count: 3
# Count: 4
# Count: 5

# %%
colors = ["red", "blue", "green"]
for color in colors:
    print("I like", color + "!")
# Out:
# I like red!
# I like blue!
# I like green!

# %% [markdown]
# # While Loop

# %%
cookies = 3
while cookies > 0: # While True (cookies left)
    print("Nom nom! One cookie gone.")
    cookies = cookies - 1
print("All gone!")
# Out:
# Nom nom! One cookie gone.
# Nom nom! One cookie gone.
# Nom nom! One cookie gone.
# All gone!

# %%
guesses += 1 # Add 1

guesses = guesses + 1

# %%
guesses = 0
secret_number = 7
guess_limit_number = 3
while guesses < guess_limit_number:
    #print("Guess my number! Hint: 7")
    guess = int(input())
    if guess == secret_number:
        print("Yes!")
        break
    guesses += 1 # Add 1
else:
    print("Too many tries!")
# Out:
# Yes!

# %% [markdown]
# # Functions

# %%
def cookie_maker(num):
    cookies = "🍪 " * num # Multiply num
    return cookies # Gift back the batch

batch = cookie_maker(3)
print(batch)
# Out:
# 🍪 🍪 🍪

# %%
def cookie_maker():
    cookies = "🍪 " * 5 # Multiply num
    return cookies # Gift back the batch

batch = cookie_maker()
print(batch)
# Out:
# 🍪 🍪 🍪 🍪 🍪

# %%
def cookie_maker(num):
    cookies = "🍪 " * 7 # Multiply num
    return cookies # Gift back the batch

batch = cookie_maker(7)
print(batch)
# Out:
# 🍪 🍪 🍪 🍪 🍪 🍪 🍪

# %%
def cookie_maker(num):
    cookies = "🍪 " * num # Multiply num
    return cookies # Gift back the batch

batch = cookie_maker(10)
print(batch)
# Out:
# 🍪 🍪 🍪 🍪 🍪 🍪 🍪 🍪 🍪 🍪

# %% [markdown]
# # Error Handling

# %%
a = 10 / 0
print(a)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 a = 10 / 0
#       2 print(a)
#
# ZeroDivisionError: division by zero

# %%
def safe_divide(a, b):
    try:
        result = a / b
    except ZeroDivisionError: # specific error
        print("Oops! Can't divide by zero - try again!")
        result = "Error"
    else:
        print("Yay, it worked!")
    finally:
        print("Math time over -  back to play!")
    return result

print(safe_divide(10, 2)) # 5.0 - Yay!
# print(safe_divide(10, 0))
# Out:
# Yay, it worked!
# Math time over -  back to play!
# 5.0

# %%
def safe_divide(a, b):
    try:
        result = a / b
    except ZeroDivisionError: # specific error
        print("Oops! Can't divide by zero - try again!")
        result = "Error"
    else:
        print("Yay, it worked!")
    finally:
        print("Math time over -  back to play!")
    return result

# print(safe_divide(10, 2)) # 5.0 - Yay!
print(safe_divide(10, 0))
# Out:
# Oops! Can't divide by zero - try again!
# Math time over -  back to play!
# Error

# %%
def safe_divide(a, b):
    try:
        result = a / b
    except Exception as e:
        print("Oops! Can't divide by zero - try again!")
        result = "Error"
    else:
        print("Yay, it worked!")
    finally:
        print("Math time over -  back to play!")
    return result

# print(safe_divide(10, 2)) # 5.0 - Yay!
print(safe_divide(10, 0))
# Out:
# Oops! Can't divide by zero - try again!
# Math time over -  back to play!
# Error

# %% [markdown]
# # Pandas

# %%
import pandas as pd # importing the pandas library

# %%
pd.__version__ # checking of pandas version
# Out:
# '2.1.4'

# %%
prices = pd.Series([10, 20, 15], index = ['ball','doll', 'car']) # creating a pandas series
print(prices)
# Out:
# ball    10
# doll    20
# car     15
# dtype: int64

# %%
# Creating a pandas data frame
import pandas as pd
df = pd.DataFrame({
    'Toy': ['ball', 'doll', 'car', 'block'],
    'Price': [10, 20, 15, 5],
    'Stock': [50, 30, 40, 100]
})
print(df)
# Out:
#      Toy  Price  Stock
# 0   ball     10     50
# 1   doll     20     30
# 2    car     15     40
# 3  block      5    100

# %%
df
# Out:
#      Toy  Price  Stock
# 0   ball     10     50
# 1   doll     20     30
# 2    car     15     40
# 3  block      5    100

# %%
df.head(2) # first 2 data
# Out:
#     Toy  Price  Stock
# 0  ball     10     50
# 1  doll     20     30

# %%
df.tail(2) # Last 2 data
# Out:
#      Toy  Price  Stock
# 2    car     15     40
# 3  block      5    100

# %% [markdown]
# # Loading a CSV file in pandas

# %%
df = pd.read_csv('toys.csv')
df = pd.read_xlsx('toys.xlsx')
df = pd.read_json('toys.json')
df = pd.read_txt('toys.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df = pd.read_csv('toys.csv')
#       2 df = pd.read_xlsx('toys.xlsx')
#       3 df = pd.read_json('toys.json')
#
# ...

# %%
df.to_csv('my_toys.csv', index=False) # save csv files

# %%
df = pd.read_csv('my_toys.csv') # load our saved csv file

# %%
df.head(3) # top 3
# Out:
#     Toy  Price  Stock
# 0  ball     10     50
# 1  doll     20     30
# 2   car     15     40

# %%
df.tail(3) # last 3
# Out:
#      Toy  Price  Stock
# 1   doll     20     30
# 2    car     15     40
# 3  block      5    100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Toy     4 non-null      object
#  1   Price   4 non-null      int64
#  2   Stock   4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.dtypes
# Out:
# Toy      object
# Price     int64
# Stock     int64
# dtype: object

# %%
df.describe()
# Out:
#            Price       Stock
# count   4.000000    4.000000
# mean   12.500000   55.000000
# std     6.454972   31.091264
# min     5.000000   30.000000
# 25%     8.750000   37.500000
# 50%    12.500000   45.000000
# 75%    16.250000   62.500000
# max    20.000000  100.000000

# %%
df.shape
# Out:
# (4, 3)

# %%
df.size
# Out:
# 12

# %%
df.columns
# Out:
# Index(['Toy', 'Price', 'Stock'], dtype='object')

# %%
df.describe(include = 'all')
# Out:
#          Toy      Price       Stock
# count      4   4.000000    4.000000
# unique     4        NaN         NaN
# top     ball        NaN         NaN
# freq       1        NaN         NaN
# mean     NaN  12.500000   55.000000
# std      NaN   6.454972   31.091264
# min      NaN   5.000000   30.000000
# 25%      NaN   8.750000   37.500000
# 50%      NaN  12.500000   45.000000
# 75%      NaN  16.250000   62.500000
# max      NaN  20.000000  100.000000

# %%
df1 = df.copy() # copy dataframe

# %%
df1.columns # check columns
# Out:
# Index(['Toy', 'Price', 'Stock'], dtype='object')

# %%
df.columns
# Out:
# Index(['Toy', 'Price', 'Stock'], dtype='object')

# %%
df1.columns = ['Item', 'Cost', 'Quantity'] # change column names

# %%
df1.columns
# Out:
# Index(['Item', 'Cost', 'Quantity'], dtype='object')

# %%
df.head()
# Out:
#      Toy  Price  Stock
# 0   ball     10     50
# 1   doll     20     30
# 2    car     15     40
# 3  block      5    100

# %%
df1.head()
# Out:
#     Item  Cost  Quantity
# 0   ball    10        50
# 1   doll    20        30
# 2    car    15        40
# 3  block     5       100

# %% [markdown]
# # Selecting or Slicing of Data

# %%
df['Toy']
# Out:
# 0     ball
# 1     doll
# 2      car
# 3    block
# Name: Toy, dtype: object

# %%
df[['Toy', 'Price']]
# Out:
#      Toy  Price
# 0   ball     10
# 1   doll     20
# 2    car     15
# 3  block      5

# %%
df.head()
# Out:
#      Toy  Price  Stock
# 0   ball     10     50
# 1   doll     20     30
# 2    car     15     40
# 3  block      5    100

# %%
df.loc[3] # Gives the values for the fourth row of each column
# Out:
# Toy      block
# Price        5
# Stock      100
# Name: 3, dtype: object

# %%
df.iloc[3]
# Out:
# Toy      block
# Price        5
# Stock      100
# Name: 3, dtype: object

# %%
df.head()
# Out:
#      Toy  Price  Stock
# 0   ball     10     50
# 1   doll     20     30
# 2    car     15     40
# 3  block      5    100

# %%
df.iloc[0] # gets the first row for all the columns
# Out:
# Toy      ball
# Price      10
# Stock      50
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# Toy      ball
# Price      10
# Stock      50
# Name: 0, dtype: object

# %%
df.head()
# Out:
#      Toy  Price  Stock
# 0   ball     10     50
# 1   doll     20     30
# 2    car     15     40
# 3  block      5    100

# %%
df.loc[1:3, 'Toy'] # gets from the second to fourth row of the column 'Toy'
# Out:
# 1     doll
# 2      car
# 3    block
# Name: Toy, dtype: object

# %%
df.iloc[1:3, 'Toy']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/envs/Tensorflow/lib/python3.12/site-packages/pandas/core/indexing.py:940, in _LocationIndexer._validate_tuple_indexer(self, key)
#     939 try:
# --> 940     self._validate_key(k, i)
#     941 except ValueError as err:
#
# File /opt/anaconda3/envs/Tensorflow/lib/python3.12/site-packages/pandas/core/indexing.py:1576, in _iLocIndexer._validate_key(self, key, axis)
#    1575 else:
# -> 1576     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ...

# %%
df.head()
# Out:
#      Toy  Price  Stock
# 0   ball     10     50
# 1   doll     20     30
# 2    car     15     40
# 3  block      5    100

# %%
df.iloc[:, 0] # Gives us everything in the first column
# Out:
# 0     ball
# 1     doll
# 2      car
# 3    block
# Name: Toy, dtype: object

# %%
df.loc[:, 0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/Tensorflow/lib/python3.12/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 df.loc[:, 0]
#
# ...

# %%
df.head()
# Out:
#      Toy  Price  Stock
# 0   ball     10     50
# 1   doll     20     30
# 2    car     15     40
# 3  block      5    100

# %%
df.iloc[1, 0]
# Out:
# 'doll'

# %%
df.loc[1, 0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/Tensorflow/lib/python3.12/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df.loc[1, 0]
#
# ...

# %%
# Creating a pandas data frame
import pandas as pd
df = pd.DataFrame({
    'Toy': ['ball', 'doll', 'car', 'block', 'NaN'],
    'Price': [10, 20, 15, 5, 25],
    'Stock': [50, 30, 40, 100, 70]
})
print(df)
# Out:
#      Toy  Price  Stock
# 0   ball     10     50
# 1   doll     20     30
# 2    car     15     40
# 3  block      5    100
# 4    NaN     25     70

# %%
df.isnull().sum()
# Out:
# Toy      0
# Price    0
# Stock    0
# dtype: int64

# %%
import pandas as pd
import numpy as np

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, np.nan, 30, 22, np.nan],
    'City': ['London', 'Manchester', np.nan, 'Bristol', 'Liverpool'],
    'Salary': [50000, 48000, np.nan, 52000, 47000],
    'Department': ['HR', np.nan, 'IT', 'Finance', 'HR']
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name   Age        City   Salary Department
# 0    Alice  25.0      London  50000.0         HR
# 1      Bob   NaN  Manchester  48000.0        NaN
# 2  Charlie  30.0         NaN      NaN         IT
# 3    David  22.0     Bristol  52000.0    Finance
# 4      Eve   NaN   Liverpool  47000.0         HR

# %%
df.head()
# Out:
#       Name   Age        City   Salary Department
# 0    Alice  25.0      London  50000.0         HR
# 1      Bob   NaN  Manchester  48000.0        NaN
# 2  Charlie  30.0         NaN      NaN         IT
# 3    David  22.0     Bristol  52000.0    Finance
# 4      Eve   NaN   Liverpool  47000.0         HR

# %%
df.isnull().sum()
# Out:
# Name          0
# Age           2
# City          1
# Salary        1
# Department    1
# dtype: int64

# %%
df.isna().sum()
# Out:
# Name          0
# Age           2
# City          1
# Salary        1
# Department    1
# dtype: int64

# %%
df.head()
# Out:
#       Name   Age        City   Salary Department
# 0    Alice  25.0      London  50000.0         HR
# 1      Bob   NaN  Manchester  48000.0        NaN
# 2  Charlie  30.0         NaN      NaN         IT
# 3    David  22.0     Bristol  52000.0    Finance
# 4      Eve   NaN   Liverpool  47000.0         HR

# %%
df1 = df.copy()

# %%
df2 = df1.copy()

# %%
df1.head()
# Out:
#       Name   Age        City   Salary Department
# 0    Alice  25.0      London  50000.0         HR
# 1      Bob   NaN  Manchester  48000.0        NaN
# 2  Charlie  30.0         NaN      NaN         IT
# 3    David  22.0     Bristol  52000.0    Finance
# 4      Eve   NaN   Liverpool  47000.0         HR

# %%
df2.head()
# Out:
#       Name   Age        City   Salary Department
# 0    Alice  25.0      London  50000.0         HR
# 1      Bob   NaN  Manchester  48000.0        NaN
# 2  Charlie  30.0         NaN      NaN         IT
# 3    David  22.0     Bristol  52000.0    Finance
# 4      Eve   NaN   Liverpool  47000.0         HR

# %%
df1['Salary'] = df1['Salary'].fillna(0) # fills null values in the selected column with zero
df1.head()
# Out:
#       Name   Age        City   Salary Department
# 0    Alice  25.0      London  50000.0         HR
# 1      Bob   NaN  Manchester  48000.0        NaN
# 2  Charlie  30.0         NaN      0.0         IT
# 3    David  22.0     Bristol  52000.0    Finance
# 4      Eve   NaN   Liverpool  47000.0         HR

# %%
df1.isna().sum()
# Out:
# Name          0
# Age           2
# City          1
# Salary        0
# Department    1
# dtype: int64

# %%
df2.head()
# Out:
#       Name   Age        City   Salary Department
# 0    Alice  25.0      London  50000.0         HR
# 1      Bob   NaN  Manchester  48000.0        NaN
# 2  Charlie  30.0         NaN      NaN         IT
# 3    David  22.0     Bristol  52000.0    Finance
# 4      Eve   NaN   Liverpool  47000.0         HR

# %%
df = df.dropna() # drops all null values

# %%
df.isnull().sum()
# Out:
# Name          0
# Age           0
# City          0
# Salary        0
# Department    0
# dtype: int64

# %%
df.head()
# Out:
#     Name   Age     City   Salary Department
# 0  Alice  25.0   London  50000.0         HR
# 3  David  22.0  Bristol  52000.0    Finance

# %%
df2.head()
# Out:
#       Name   Age        City   Salary Department
# 0    Alice  25.0      London  50000.0         HR
# 1      Bob   NaN  Manchester  48000.0        NaN
# 2  Charlie  30.0         NaN      NaN         IT
# 3    David  22.0     Bristol  52000.0    Finance
# 4      Eve   NaN   Liverpool  47000.0         HR

# %%
df3 = df2.copy()

# %%
df4 = df2.copy()

# %%
df2.head()
# Out:
#       Name   Age        City   Salary Department
# 0    Alice  25.0      London  50000.0         HR
# 1      Bob   NaN  Manchester  48000.0        NaN
# 2  Charlie  30.0         NaN      NaN         IT
# 3    David  22.0     Bristol  52000.0    Finance
# 4      Eve   NaN   Liverpool  47000.0         HR

# %%
df2['Salary'].fillna(0) # fills null values in the selected column with zero
# Out:
# 0    50000.0
# 1    48000.0
# 2        0.0
# 3    52000.0
# 4    47000.0
# Name: Salary, dtype: float64

# %%
df2.head()
# Out:
#       Name   Age        City   Salary Department
# 0    Alice  25.0      London  50000.0         HR
# 1      Bob   NaN  Manchester  48000.0        NaN
# 2  Charlie  30.0         NaN      NaN         IT
# 3    David  22.0     Bristol  52000.0    Finance
# 4      Eve   NaN   Liverpool  47000.0         HR

# %%
df2.isna().sum()
# Out:
# Name          0
# Age           2
# City          1
# Salary        1
# Department    1
# dtype: int64

# %%
df2['Salary'] = df2['Salary'].fillna(0) # fills null values in the selected column with zero

# %%
df2.isna().sum()
# Out:
# Name          0
# Age           2
# City          1
# Salary        0
# Department    1
# dtype: int64

# %%
df2.head()
# Out:
#       Name   Age        City   Salary Department
# 0    Alice  25.0      London  50000.0         HR
# 1      Bob   NaN  Manchester  48000.0        NaN
# 2  Charlie  30.0         NaN      0.0         IT
# 3    David  22.0     Bristol  52000.0    Finance
# 4      Eve   NaN   Liverpool  47000.0         HR

# %%
df3.head()
# Out:
#       Name   Age        City   Salary Department
# 0    Alice  25.0      London  50000.0         HR
# 1      Bob   NaN  Manchester  48000.0        NaN
# 2  Charlie  30.0         NaN      NaN         IT
# 3    David  22.0     Bristol  52000.0    Finance
# 4      Eve   NaN   Liverpool  47000.0         HR

# %%
df3.isna().sum()
# Out:
# Name          0
# Age           2
# City          1
# Salary        1
# Department    1
# dtype: int64

# %%
df3.dropna() # drops all null values
# Out:
#     Name   Age     City   Salary Department
# 0  Alice  25.0   London  50000.0         HR
# 3  David  22.0  Bristol  52000.0    Finance

# %%
df3.head()
# Out:
#       Name   Age        City   Salary Department
# 0    Alice  25.0      London  50000.0         HR
# 1      Bob   NaN  Manchester  48000.0        NaN
# 2  Charlie  30.0         NaN      NaN         IT
# 3    David  22.0     Bristol  52000.0    Finance
# 4      Eve   NaN   Liverpool  47000.0         HR

# %%
df3.isna().sum()
# Out:
# Name          0
# Age           2
# City          1
# Salary        1
# Department    1
# dtype: int64

# %%
df3 = df3.dropna() # drops all null values

# %%
df3.head()
# Out:
#     Name   Age     City   Salary Department
# 0  Alice  25.0   London  50000.0         HR
# 3  David  22.0  Bristol  52000.0    Finance

# %%
df3.isna().sum()
# Out:
# Name          0
# Age           0
# City          0
# Salary        0
# Department    0
# dtype: int64

# %%
df5 = df4.copy()

# %%
df6 = df4.copy()

# %%
df4.head()
# Out:
#       Name   Age        City   Salary Department
# 0    Alice  25.0      London  50000.0         HR
# 1      Bob   NaN  Manchester  48000.0        NaN
# 2  Charlie  30.0         NaN      NaN         IT
# 3    David  22.0     Bristol  52000.0    Finance
# 4      Eve   NaN   Liverpool  47000.0         HR

# %%
df4.dtypes
# Out:
# Name           object
# Age           float64
# City           object
# Salary        float64
# Department     object
# dtype: object

# %%
df4['Salary'] = df4['Salary'].fillna(0)

# %%
df4.head()
# Out:
#       Name   Age        City   Salary Department
# 0    Alice  25.0      London  50000.0         HR
# 1      Bob   NaN  Manchester  48000.0        NaN
# 2  Charlie  30.0         NaN      0.0         IT
# 3    David  22.0     Bristol  52000.0    Finance
# 4      Eve   NaN   Liverpool  47000.0         HR

# %%
df4.dtypes
# Out:
# Name           object
# Age           float64
# City           object
# Salary        float64
# Department     object
# dtype: object

# %%
df4['Salary'] = df4['Salary'].astype(int)

# %%
df4.dtypes
# Out:
# Name           object
# Age           float64
# City           object
# Salary          int64
# Department     object
# dtype: object

# %%
df4.head()
# Out:
#       Name   Age        City  Salary Department
# 0    Alice  25.0      London   50000         HR
# 1      Bob   NaN  Manchester   48000        NaN
# 2  Charlie  30.0         NaN       0         IT
# 3    David  22.0     Bristol   52000    Finance
# 4      Eve   NaN   Liverpool   47000         HR

# %%
df4['Age'] = df4['Age'].fillna(0)

# %%
df4['Age'] = df4['Age'].astype(int)

# %%
df4.dtypes
# Out:
# Name          object
# Age            int64
# City          object
# Salary         int64
# Department    object
# dtype: object

# %%
df4.head()
# Out:
#       Name  Age        City  Salary Department
# 0    Alice   25      London   50000         HR
# 1      Bob    0  Manchester   48000        NaN
# 2  Charlie   30         NaN       0         IT
# 3    David   22     Bristol   52000    Finance
# 4      Eve    0   Liverpool   47000         HR

# %%
# Creating a pandas data frame
import pandas as pd
df = pd.DataFrame({
    'Toy': ['ball', 'doll', 'car', 'block'],
    'Price': [10, 20, 15, 5],
    'Stock': [50, 30, 40, 100]
})
print(df)
# Out:
#      Toy  Price  Stock
# 0   ball     10     50
# 1   doll     20     30
# 2    car     15     40
# 3  block      5    100

# %%
df.head()
# Out:
#      Toy  Price  Stock
# 0   ball     10     50
# 1   doll     20     30
# 2    car     15     40
# 3  block      5    100

# %%
df.agg({'Price': 'sum', 'Stock': 'max'}) # aggregates
# Out:
# Price     50
# Stock    100
# dtype: int64

# %%
df.groupby('Toy')['Price'].mean() # groupby and averages
# Out:
# Toy
# ball     10.0
# block     5.0
# car      15.0
# doll     20.0
# Name: Price, dtype: float64

# %%
df.groupby('Toy')['Price'].mean().sort_values(ascending=True) # groupby and orderby. ascending=True means ascending order
# Out:
# Toy
# block     5.0
# ball     10.0
# car      15.0
# doll     20.0
# Name: Price, dtype: float64

# %%
df.groupby('Toy')['Price'].mean().sort_values(ascending=False) # groupby and orderby. ascending=False means descending order
# Out:
# Toy
# doll     20.0
# car      15.0
# ball     10.0
# block     5.0
# Name: Price, dtype: float64

# %%
df.groupby('Toy')['Price'].mean().reset_index(name='Mean Price').sort_values(by='Mean Price', ascending=False)
# Out:
#      Toy  Mean Price
# 3   doll        20.0
# 2    car        15.0
# 0   ball        10.0
# 1  block         5.0

# %%
df.groupby('Toy')['Price'].mean().reset_index(name='Mean Price').sort_values('Mean Price', ascending=False)
# Out:
#      Toy  Mean Price
# 3   doll        20.0
# 2    car        15.0
# 0   ball        10.0
# 1  block         5.0

# %% [markdown]
# ###### If you are using a chain process you need to use a bracket to specify to python that is is one block of code

# %%
(df.groupby('Toy')['Price']
 .mean()
 .reset_index(name='Mean Price') # Renames the aggregated column for clarity
 .sort_values('Mean Price', ascending=False) # descending order
)
# Out:
#      Toy  Mean Price
# 3   doll        20.0
# 2    car        15.0
# 0   ball        10.0
# 1  block         5.0

# %%
# Creating a pandas data frame
import pandas as pd
df1 = pd.DataFrame({
    'Price': [10, 20, 15, 5],
    'Stock': [50, 30, 40, 100]
})
print(df1)
# Out:
#    Price  Stock
# 0     10     50
# 1     20     30
# 2     15     40
# 3      5    100

# %%
df1.head()
# Out:
#    Price  Stock
# 0     10     50
# 1     20     30
# 2     15     40
# 3      5    100

# %%
df1.corr()
# Out:
#         Price   Stock
# Price  1.0000 -0.9135
# Stock -0.9135  1.0000

# %%
df.head()
# Out:
#      Toy  Price  Stock
# 0   ball     10     50
# 1   doll     20     30
# 2    car     15     40
# 3  block      5    100

# %%
# Dataframe 1: Prices
data_prices = {
    'Toy': ['Ball', 'Car', 'Doll', 'Train', 'Puzzle'],
    'Price': [10.00, 20.00, 30.00, 45.00, 15.00]
}
df1 = pd.DataFrame(data_prices)

# Dataframe 2: Inventory
data_inventory = {
    'Toy': ['Ball', 'Car', 'Doll', 'Truck', 'Robot'],
    'Stock': [50, 40, 30, 25, 10]
}
df2 = pd.DataFrame(data_inventory)

# %%
df1.head() # Prices dataframe
# Out:
#       Toy  Price
# 0    Ball   10.0
# 1     Car   20.0
# 2    Doll   30.0
# 3   Train   45.0
# 4  Puzzle   15.0

# %%
df2.head() # Inventory dataframe
# Out:
#      Toy  Stock
# 0   Ball     50
# 1    Car     40
# 2   Doll     30
# 3  Truck     25
# 4  Robot     10

# %% [markdown]
# ## Inner Join
# ##### Only keeps rows that have a match in both DataFrame.

# %%
df3 = pd.merge(df1, df2, on='Toy', how='inner') 
df3
# Out:
#     Toy  Price  Stock
# 0  Ball   10.0     50
# 1   Car   20.0     40
# 2  Doll   30.0     30

# %% [markdown]
# ## Left Join
# ##### Keeps all rows from df1 and the matching rows from df2. Missing values in df2 columns will be filled with NaN.

# %%
df4 = pd.merge(df1, df2, on='Toy', how='left') 
df4
# Out:
#       Toy  Price  Stock
# 0    Ball   10.0   50.0
# 1     Car   20.0   40.0
# 2    Doll   30.0   30.0
# 3   Train   45.0    NaN
# 4  Puzzle   15.0    NaN

# %% [markdown]
# ## Right Join
# ##### Keeps all rows from df2 and the matching rows from df1. Missing values in df1 columns will be filled with NaN.

# %%
df5 = pd.merge(df1, df2, on='Toy', how='right') 
df5
# Out:
#      Toy  Price  Stock
# 0   Ball   10.0     50
# 1    Car   20.0     40
# 2   Doll   30.0     30
# 3  Truck    NaN     25
# 4  Robot    NaN     10

# %% [markdown]
# ## Outer Join
# ##### Keeps all rows from both DataFrames(a full union). Missing values will be filled with NaN.

# %%
df6 = pd.merge(df1, df2, on='Toy', how='outer') 
df6
# Out:
#       Toy  Price  Stock
# 0    Ball   10.0   50.0
# 1     Car   20.0   40.0
# 2    Doll   30.0   30.0
# 3   Train   45.0    NaN
# 4  Puzzle   15.0    NaN
# 5   Truck    NaN   25.0
# 6   Robot    NaN   10.0

# %%
# Dataframe 1: Prices
data_prices = {
    'Toy': ['Ball', 'Car', 'Doll', 'Train', 'Puzzle'],
    'Price': [10.00, 20.00, 30.00, 45.00, 15.00],
    'Stock': [60, 80, 35, 45, 90]
}
df7 = pd.DataFrame(data_prices)

# Dataframe 2: Inventory
data_inventory = {
    'Toy': ['Ball', 'Car', 'Doll', 'Truck', 'Robot'],
    'Stock': [50, 40, 30, 25, 10],
    'Tools': ['Bag', 'Sack', 'Pan', 'Tray', 'Mouse'],
}
df8 = pd.DataFrame(data_inventory)

# %%
df7.head()
# Out:
#       Toy  Price  Stock
# 0    Ball   10.0     60
# 1     Car   20.0     80
# 2    Doll   30.0     35
# 3   Train   45.0     45
# 4  Puzzle   15.0     90

# %%
df8.head()
# Out:
#      Toy  Stock  Tools
# 0   Ball     50    Bag
# 1    Car     40   Sack
# 2   Doll     30    Pan
# 3  Truck     25   Tray
# 4  Robot     10  Mouse

# %%
df9 = pd.merge(df7, df8, on='Toy', how='inner') 
df9
# Out:
#     Toy  Price  Stock_x  Stock_y Tools
# 0  Ball   10.0       60       50   Bag
# 1   Car   20.0       80       40  Sack
# 2  Doll   30.0       35       30   Pan

# %%
df10 = pd.merge(df7, df8, on='Toy', how='left') 
df10
# Out:
#       Toy  Price  Stock_x  Stock_y Tools
# 0    Ball   10.0       60     50.0   Bag
# 1     Car   20.0       80     40.0  Sack
# 2    Doll   30.0       35     30.0   Pan
# 3   Train   45.0       45      NaN   NaN
# 4  Puzzle   15.0       90      NaN   NaN

# %%
df11 = pd.merge(df7, df8, on='Toy', how='right') 
df11
# Out:
#      Toy  Price  Stock_x  Stock_y  Tools
# 0   Ball   10.0     60.0       50    Bag
# 1    Car   20.0     80.0       40   Sack
# 2   Doll   30.0     35.0       30    Pan
# 3  Truck    NaN      NaN       25   Tray
# 4  Robot    NaN      NaN       10  Mouse

# %%
df12 = pd.merge(df7, df8, on='Toy', how='outer') 
df12
# Out:
#       Toy  Price  Stock_x  Stock_y  Tools
# 0    Ball   10.0     60.0     50.0    Bag
# 1     Car   20.0     80.0     40.0   Sack
# 2    Doll   30.0     35.0     30.0    Pan
# 3   Train   45.0     45.0      NaN    NaN
# 4  Puzzle   15.0     90.0      NaN    NaN
# 5   Truck    NaN      NaN     25.0   Tray
# 6   Robot    NaN      NaN     10.0  Mouse

# %% [markdown]
# # Concat

# %%
# Dataframe 1
data1 = {
        'A': [1, 3],
        'B': [2, 5],
        'C': [5, 8],
        'D': [6, 9] 
}
df13 = pd.DataFrame(data1)

# Dataframe 2
data2 = {
        'E': [4, 7],
        'F': [5, 12],
        'G': [6, 15],
        'H': [7, 20] 
}
df14 = pd.DataFrame(data2)

# %%
df13
# Out:
#    A  B  C  D
# 0  1  2  5  6
# 1  3  5  8  9

# %%
df14
# Out:
#    E   F   G   H
# 0  4   5   6   7
# 1  7  12  15  20

# %%
pd.concat([df13, df14])
# Out:
#      A    B    C    D    E     F     G     H
# 0  1.0  2.0  5.0  6.0  NaN   NaN   NaN   NaN
# 1  3.0  5.0  8.0  9.0  NaN   NaN   NaN   NaN
# 0  NaN  NaN  NaN  NaN  4.0   5.0   6.0   7.0
# 1  NaN  NaN  NaN  NaN  7.0  12.0  15.0  20.0

# %%
pd.concat([df13, df14], axis=0)
# Out:
#      A    B    C    D    E     F     G     H
# 0  1.0  2.0  5.0  6.0  NaN   NaN   NaN   NaN
# 1  3.0  5.0  8.0  9.0  NaN   NaN   NaN   NaN
# 0  NaN  NaN  NaN  NaN  4.0   5.0   6.0   7.0
# 1  NaN  NaN  NaN  NaN  7.0  12.0  15.0  20.0

# %%
pd.concat([df13, df14], axis=1)
# Out:
#    A  B  C  D  E   F   G   H
# 0  1  2  5  6  4   5   6   7
# 1  3  5  8  9  7  12  15  20

# %%
# Creating a pandas data frame
import pandas as pd
df15 = pd.DataFrame({
    'Toy': ['ball', 'doll', 'car', 'block'],
    'Price': [10, 20, 15, 5],
    'Stock': [50, 30, 40, 100]
})
print(df15)
# Out:
#      Toy  Price  Stock
# 0   ball     10     50
# 1   doll     20     30
# 2    car     15     40
# 3  block      5    100

# %%
import matplotlib as plt

# %%
df15.plot(kind='bar', x='Toy', y='Price');

# %%
"""
10000-row dirty dataset generator
Matches the flaws in the 6-row example:
  – duplicate names
  – None / NaN / empty strings
  – negative ages
  – invalid dates
  – missing salaries
  – stray whitespace & mixed-case names
  – rare exotic Unicode
  – leading zeros in IDs
  – occasional extra columns (ragged CSV feel)
"""

import pandas as pd
import numpy as np
from datetime import date, timedelta
import random
import warnings
warnings.filterwarnings('ignore')

RNG = np.random.default_rng(42)
SIZE = 10000

# 1) ID: mostly sequential but with gaps and leading zeros
ids = list(range(1, SIZE + 1))
RNG.shuffle(ids)
ids = [f"{i:05d}" for i in ids]          # 00001, 00002 …

# 2) Names: common, rare, empty, None, Unicode, spaces
first = ["Alice", "Bob", "Charlie", "Diana", "Eve", "Frank", "Grace", None, "", "  ", "bob", "ALICE"]
last  = ["Smith", "Johnson", "Lee", "O'Connor", "van der Waal", "Михайлов", "🐼", None, ""]
names = [f"{RNG.choice(first)} {RNG.choice(last)}" for _ in range(SIZE)]
# sprinkle pure None
for i in RNG.choice(SIZE, size=300, replace=False):
    names[i] = None

# 3) Age: positives, negatives, NaN, floats
ages = RNG.normal(loc=35, scale=12, size=SIZE)
ages[RNG.random(SIZE) < 0.08] = np.nan
ages[RNG.random(SIZE) < 0.02] = RNG.integers(-10, 0)

# 4) Salary: missing, negatives, huge, cents
salaries = RNG.lognormal(mean=11, sigma=0.5, size=SIZE)
salaries[RNG.random(SIZE) < 0.07] = np.nan
salaries[RNG.random(SIZE) < 0.01] = -RNG.exponential(1000)
salaries = np.round(salaries, 2)

# 5) Date: valid, impossible, mis-formatted
start = date(2020, 1, 1)
def random_date():
    if RNG.random() < 0.05:
        return RNG.choice(["invalid", "2021-02-30", "13/45/2022", "", "N/A"])
    delta = timedelta(days=int(RNG.integers(0, 1500)))
    d = start + delta
    if RNG.random() < 0.10:
        return d.strftime("%d/%m/%Y")
    return str(d)

dates = [random_date() for _ in range(SIZE)]

# 6) Category: A B C plus garbage
cats = ["A", "B", "C", None, "", "a", "b", "🎲"]
categories = RNG.choice(cats, size=SIZE, p=[0.3, 0.3, 0.3, 0.03, 0.03, 0.02, 0.01, 0.01])

# 7) Build DataFrame
df = pd.DataFrame({
    "id": ids,
    "name": names,
    "age": ages,
    "salary": salaries,
    "date": dates,
    "category": categories
})

# 8) Extra dirt: duplicate rows, swapped columns, trailing spaces
df = pd.concat([df, df.sample(n=200, random_state=RNG)], ignore_index=True)   # 200 dupes
df["name"] = df["name"].astype(str).str.strip() + RNG.choice(["", " ", "  "], size=len(df))
df.iloc[RNG.choice(len(df), 50), 0] = ""   # blank ids
df.iloc[RNG.choice(len(df), 50), 2] = "thirty-five"  # string in age

# 9) Save
df.to_csv("messy_dataset.csv", index=False)
print("messy_dataset.csv created →", df.shape)
print(df.head(10))
# Out:
# messy_dataset.csv created → (10200, 6)
#       id                name        age     salary        date category
# 0  08133          None Lee    16.741619  102784.00  2022-11-14        B
# 1           Diana Михайлов    43.415811   48330.35  2020-02-19        a
# 2  00720        Charlie None  28.195627  126557.90  2023-03-29        A
# 3  08238           bob Smith  39.515083   71411.52  2022-11-05        A
# 4  04556        ALICE Smith   45.646664  158614.65  2020-06-20        B
# 5  06652           Frank 🐼    38.934451        NaN  2022-06-23        B
# 6  05651       Diana Johnson  44.589521   43432.43  13/45/2022        B
# 7  09035           Alice 🐼    10.200329   53309.34  2024-01-10        A
# 8  01261  Alice van der Waal   29.08572   32652.40  2022-04-26        C
# 9  00645                Eve    48.23692   95124.50  2022-09-05        C

# %%
df.head(10)
# Out:
#       id                name        age     salary        date category
# 0  08133          None Lee    16.741619  102784.00  2022-11-14        B
# 1           Diana Михайлов    43.415811   48330.35  2020-02-19        a
# 2  00720        Charlie None  28.195627  126557.90  2023-03-29        A
# 3  08238           bob Smith  39.515083   71411.52  2022-11-05        A
# 4  04556        ALICE Smith   45.646664  158614.65  2020-06-20        B
# 5  06652           Frank 🐼    38.934451        NaN  2022-06-23        B
# 6  05651       Diana Johnson  44.589521   43432.43  13/45/2022        B
# 7  09035           Alice 🐼    10.200329   53309.34  2024-01-10        A
# 8  01261  Alice van der Waal   29.08572   32652.40  2022-04-26        C
# 9  00645                Eve    48.23692   95124.50  2022-09-05        C

# %%
df.tail(10)
# Out:
#           id              name        age    salary        date category
# 10190  05006   Alice Михайлов   60.029926  45347.51  2023-03-30        B
# 10191  05316      Diana Smith   36.856868  69587.20  2020-12-30        A
# 10192  08049     None Johnson         NaN  54285.37  2022-11-07        C
# 10193  09524   Diana Михайлов    46.04597  60838.92  2020-10-19        A
# 10194  06246      ALICE None    46.419879  84660.20                    C
# 10195  02811             Smith        NaN  88323.82  2023-06-13        C
# 10196  06218  bob van der Waal  26.694159  63904.94  2024-02-02        B
# 10197  06504          Charlie   32.659107  15803.28  2021-11-10        C
# 10198  04692         bob Smith  60.143554  50487.89  2023-06-22        A
# 10199  08958         Charlie          NaN  55136.62  2021-05-06     None

# %%
df.dtypes
# Out:
# id           object
# name         object
# age          object
# salary      float64
# date         object
# category     object
# dtype: object

# %%
df.size
# Out:
# 61200

# %%
df.shape
# Out:
# (10200, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10200 entries, 0 to 10199
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        10200 non-null  object
#  1   name      10200 non-null  object
#  2   age       9393 non-null   object
#  3   salary    9524 non-null   float64
#  4   date      10200 non-null  object
#  5   category  9923 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 478.3+ KB

# %%
df.describe()
# Out:
#               salary
# count    9524.000000
# mean    66424.999071
# std     36477.816459
# min       -30.040000
# 25%     41873.285000
# 50%     58793.045000
# 75%     82240.572500
# max    392309.920000

# %%
df.describe(include='all')
# Out:
#            id   name     age         salary        date category
# count   10200  10200  9393.0    9524.000000       10200     9923
# unique   9954    294  8971.0            NaN        2164        7
# top             None    -6.0            NaN  13/45/2022        B
# freq       50    197   201.0            NaN         119     3111
# mean      NaN    NaN     NaN   66424.999071         NaN      NaN
# std       NaN    NaN     NaN   36477.816459         NaN      NaN
# min       NaN    NaN     NaN     -30.040000         NaN      NaN
# 25%       NaN    NaN     NaN   41873.285000         NaN      NaN
# 50%       NaN    NaN     NaN   58793.045000         NaN      NaN
# 75%       NaN    NaN     NaN   82240.572500         NaN      NaN
# max       NaN    NaN     NaN  392309.920000         NaN      NaN

# %%
df.isnull().sum()
# Out:
# id            0
# name          0
# age         807
# salary      676
# date          0
# category    277
# dtype: int64

# %%
df.isna().sum()
# Out:
# id            0
# name          0
# age         807
# salary      676
# date          0
# category    277
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10195    False
# 10196    False
# 10197     True
# 10198    False
# 10199    False
# Length: 10200, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 56

# %%
duplicate_rows_df = df[df.duplicated()]
duplicate_rows_df
# Out:
#           id                  name        age     salary        date category
# 10006  04280  Charlie van der Waal  27.506392   71272.04  2021-06-11        B
# 10007  05113       Charlie Smith          NaN   72510.83  2021-01-10        C
# 10009  07007          Grace None          NaN        NaN  2021-11-01        A
# 10011  01735   Grace van der Waal         NaN  181071.86  2020-12-11     None
# 10013  04871      Alice Михайлов    37.889299   40807.27  2020-12-05        C
# 10015  02144      Frank O'Connor    17.876179   35368.76  2020-01-16        C
# 10016  08127         None O'Connor  51.103991   70605.62  2021-12-09        B
# 10019  06045              None 🐼    16.329463  109945.56  2023-01-04        B
# 10021  01918         Bob Johnson    38.242005   49217.47  2022-03-08        C
# 10023  08210           bob Smith    32.521784   27080.42  24/02/2022        C
# 10030  09574                ALICE    24.21752     -30.04  2022-09-18        C
# ...
