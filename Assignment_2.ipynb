# %% [markdown]
# ## Exercise 1a

# %%
fav_fruits = ['apple', 'pawpaw', 'pineapple', 'banana']
print(fav_fruits)
print(len(fav_fruits))
print(fav_fruits[1])
# Out:
# ['apple', 'pawpaw', 'pineapple', 'banana']
# 4
# pawpaw

# %% [markdown]
# ## Exercise 1b

# %%
start_with_toys = ['ball', 'doll']
start_with_toys.append('car')
start_with_toys.pop(0)
print(start_with_toys)
# Out:
# ['doll', 'car']

# %% [markdown]
# ## Exercise 2a

# %%
animal_sounds = ('meow', 'woof', 'moo')
print(animal_sounds)
print(animal_sounds[1])
# Out:
# ('meow', 'woof', 'moo')
# woof

# %% [markdown]
# ## Exercise 2b

# %%
animal_sounds[1] = 'bark'
#this will return an error, tuples are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 animal_sounds[1] = 'bark'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Exercise 3a

# %%
pets_dict = {'cat':'fluffy', 'dog':'loyal', 'bird':'chirpy'}
print(pets_dict)
pets_dict['dog']
# Out:
# {'cat': 'fluffy', 'dog': 'loyal', 'bird': 'chirpy'}
# 'loyal'

# %% [markdown]
# ## Exercise 3b

# %%
pets_dict['fish'] = 'swimmy'
del pets_dict['bird']

# %% [markdown]
# ## Exercise 3c

# %%
pets_dict.keys()
pets_dict.values()

if 'cat' in pets_dict:
    print('Yes')
else:
    print('No')
# Out:
# Yes
