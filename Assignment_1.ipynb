# %% [markdown]
# ## Exercise 1

# %%
age = 25

print(age)
print(type(age))
# Out:
# 25
# <class 'int'>

# %%
name = "Olaoluwa"
print(f"Hi,",name,"!")
# Out:
# Hi, Olaoluwa !

# %%
is_sunny = True
print(is_sunny)
# Out:
# True

# %%
height_feet = 5.9
height_inches = height_feet * 12

print(height_inches)
# Out:
# 70.80000000000001

# %% [markdown]
# ## Exercise 2

# %%
apples = 6
oranges = 4

total = apples + oranges
average = total / 2
leftover = total % 5

print(total)
print(average)
print(leftover)
# Out:
# 10
# 5.0
# 0

# %%
greeting = "Hello"
full_greeting = greeting + ", world"
rep = "Fun!" * 3
print(greeting)
print(full_greeting)
print(rep)
# Out:
# Hello
# Hello, world
# Fun!Fun!Fun!

# %%
username = input("What is your name?")
print("Nice to meet you",username,"!")

userage = int(input("How old are you?"))
print("Next year I will be",userage + 1)
# Out:
# What is your name? Olaoluwa
# Nice to meet you Olaoluwa !
# How old are you? 25
# Next year I will be 26

# %% [markdown]
# ## Exercise 3

# %%
num = int(input("Enter a number: "))

if num > 10:
    print("Big")
elif num > 5:
    print("Medium")
else:
    print("Small")
# Out:
# Enter a number:  20
# Big
